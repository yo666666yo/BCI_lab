# %% [markdown]
# #Requirements

# %%
# !pip3 install moabb
# Out:
# Requirement already satisfied: moabb in /usr/local/lib/python3.12/dist-packages (1.2.0)
# Requirement already satisfied: PyYAML<7.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from moabb) (6.0.3)
# Requirement already satisfied: coverage<8.0.0,>=7.0.1 in /usr/local/lib/python3.12/dist-packages (from moabb) (7.11.0)
# Requirement already satisfied: edfio<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from moabb) (0.4.10)
# Requirement already satisfied: edflib-python<2.0.0,>=1.0.6 in /usr/local/lib/python3.12/dist-packages (from moabb) (1.0.8)
# Requirement already satisfied: h5py<4.0.0,>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from moabb) (3.15.0)
# Requirement already satisfied: matplotlib<4.0.0,>=3.6.2 in /usr/local/lib/python3.12/dist-packages (from moabb) (3.10.0)
# Requirement already satisfied: memory-profiler<0.62.0,>=0.61.0 in /usr/local/lib/python3.12/dist-packages (from moabb) (0.61.0)
# Requirement already satisfied: mne<2.0.0,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from moabb) (1.10.2)
# Requirement already satisfied: mne-bids>=0.14 in /usr/local/lib/python3.12/dist-packages (from moabb) (0.17.0)
# Requirement already satisfied: numpy<2.0,>=1.22 in /usr/local/lib/python3.12/dist-packages (from moabb) (1.26.4)
# Requirement already satisfied: pandas>=1.5.2 in /usr/local/lib/python3.12/dist-packages (from moabb) (2.2.2)
# Requirement already satisfied: pooch<2.0.0,>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from moabb) (1.8.2)
# Requirement already satisfied: pyriemann<0.8,>=0.7 in /usr/local/lib/python3.12/dist-packages (from moabb) (0.7)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.12/dist-packages (from moabb) (2.32.4)
# Requirement already satisfied: scikit-learn<1.6 in /usr/local/lib/python3.12/dist-packages (from moabb) (1.5.2)
# Requirement already satisfied: scipy<2.0.0,>=1.9.3 in /usr/local/lib/python3.12/dist-packages (from moabb) (1.16.2)
# Requirement already satisfied: seaborn<0.13.0,>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from moabb) (0.12.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.64.1 in /usr/local/lib/python3.12/dist-packages (from moabb) (4.67.1)
# Requirement already satisfied: urllib3<2.0.0,>=1.26.15 in /usr/local/lib/python3.12/dist-packages (from moabb) (1.26.20)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.6.2->moabb) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.6.2->moabb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.6.2->moabb) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.6.2->moabb) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.6.2->moabb) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.6.2->moabb) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.6.2->moabb) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.6.2->moabb) (2.9.0.post0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from memory-profiler<0.62.0,>=0.61.0->moabb) (5.9.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from mne<2.0.0,>=1.7.0->moabb) (4.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from mne<2.0.0,>=1.7.0->moabb) (3.1.6)
# Requirement already satisfied: lazy-loader>=0.3 in /usr/local/lib/python3.12/dist-packages (from mne<2.0.0,>=1.7.0->moabb) (0.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.2->moabb) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.2->moabb) (2025.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch<2.0.0,>=1.6.0->moabb) (4.5.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from pyriemann<0.8,>=0.7->moabb) (1.5.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->moabb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->moabb) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->moabb) (2025.10.5)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<1.6->moabb) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.6.2->moabb) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->mne<2.0.0,>=1.7.0->moabb) (3.0.3)

# %% [markdown]
# #Define Networks

# %%
import torch
from torch import nn
from torch.nn import functional as F

class EEG_TCNet(nn.Module):
    def __init__(self, F1, F2, F_T, K_E, K_T, n_chan, n_cls, dropout_E, dropout_T, L=2):
        super(EEG_TCNet, self).__init__()
        self.blk_1 = nn.Sequential(
            nn.Conv2d(
                1,
                F1,
                kernel_size=(1, K_E),
                padding=(0, K_E//2)
            ),
            nn.BatchNorm2d(F1)
        )

        self.blk_2 = nn.Sequential(
            nn.Conv2d(
                F1,
                F1 * 2,
                kernel_size=(n_chan, 1),
                groups=F1
            ),
            nn.BatchNorm2d(F1 * 2),
            nn.ELU(),
            nn.AvgPool2d(kernel_size=(1, 8), stride=(1, 8)),
            nn.Dropout(p=dropout_E)
        )

        self.blk_3 = nn.Sequential(
            # Depthwise conv
            nn.Conv2d(
                F1 * 2,
                F1 * 2,
                kernel_size=(1, 16),
                groups=F1 * 2,
                padding=(0, 8)
            ),
            # Pointwise conv
            nn.Conv2d(
                F1 * 2,
                F2,
                kernel_size=(1, 1)
            ),
            nn.BatchNorm2d(F2),
            nn.ELU(),
            nn.AvgPool2d(kernel_size=(1, 8), stride=(1, 8)),
            nn.Dropout(p=dropout_E)
        )

        self.tcn_blocks = nn.ModuleList()
        for i in range(L):
            dilation = 2 ** i
            in_channels = F2 if i == 0 else F_T
            self.tcn_blocks.append(
                TCN_ResidualBlock(
                    in_channels=in_channels,
                    out_channels=F_T,
                    kernel_size=K_T,
                    dilation=dilation,
                    dropout=dropout_T
                )
            )
        self.blk_5 = nn.Sequential(
            nn.AdaptiveAvgPool2d((1, 1)),
            nn.Flatten(),
            nn.Linear(F_T, n_cls)
        )

    def forward(self, x):
        x = self.blk_1(x)
        x = self.blk_2(x)
        x = self.blk_3(x)
        for tcn_block in self.tcn_blocks:
            x = tcn_block(x)

        x = self.blk_5(x)
        return x


class TCN_ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, dilation, dropout):
        super(TCN_ResidualBlock, self).__init__()
        self.dilation = dilation
        self.kernel_size = kernel_size
        self.left_pad = dilation * (kernel_size - 1)

        self.conv1 = nn.Sequential(
            nn.Conv2d(
                in_channels,
                out_channels,
                kernel_size=(1, kernel_size),
                dilation=(1, dilation)
            ),
            nn.BatchNorm2d(out_channels),
            nn.ELU(),
            nn.Dropout(p=dropout)
        )

        self.conv2 = nn.Sequential(
            nn.Conv2d(
                out_channels,
                out_channels,
                kernel_size=(1, kernel_size),
                dilation=(1, dilation)
            ),
            nn.BatchNorm2d(out_channels),
            nn.ELU(),
            nn.Dropout(p=dropout)
        )

        if in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=(1, 1)),
                nn.BatchNorm2d(out_channels)
            )
        else:
            self.shortcut = nn.Identity()

    def forward(self, x):
        residual = self.shortcut(x)
        x = F.pad(x, (self.left_pad, 0, 0, 0), mode='constant', value=0)
        x = self.conv1(x)
        x = F.pad(x, (self.left_pad, 0, 0, 0), mode='constant', value=0)
        x = self.conv2(x)
        return x + residual

# %% [markdown]
# #Train & Test
# ####using BCI competition IV 2a

# %%
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, cohen_kappa_score
import matplotlib.pyplot as plt
from moabb import datasets
from moabb.paradigms import MotorImagery
from collections import Counter
import numpy as np

def create_eeg_tcnet_fixed(n_chan=22, n_cls=4):
    return EEG_TCNet(
        F1=8, F2=16, F_T=12, K_E=32, K_T=4,
        n_chan=n_chan, n_cls=n_cls,
        dropout_E=0.2, dropout_T=0.3, L=2
    )


# train & test
def train_eeg_tcnet():
    # using BCI Competition IV 2a dataset
    dataset = datasets.BNCI2014_001()
    paradigm = MotorImagery(n_classes=4, tmin=0.5, tmax=4.0)# MI

    subjects = dataset.subject_list
    print(f"Subjects: {subjects}")
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")

    all_results = []
    all_kappa_scores = []
    all_loss_histories = []
    all_val_acc_histories = []

    # LOO-CV
    for test_subj in subjects:
        train_subs = [s for s in subjects if s != test_subj]

        X_train, y_train, _ = paradigm.get_data(dataset=dataset, subjects=train_subs)
        X_val, y_val, _ = paradigm.get_data(dataset=dataset, subjects=[test_subj])
        le = LabelEncoder()
        y_train = le.fit_transform(y_train)
        y_val = le.transform(y_val)

        # processing imbalanced data
        class_counts = Counter(y_train)
        total_samples = len(y_train)
        weights = torch.tensor([1.0 / class_counts[i] for i in range(len(class_counts))]).to(device)
        criterion = nn.CrossEntropyLoss(weight=weights)

        # normalization
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train.reshape(X_train.shape[0], -1)).reshape(X_train.shape)
        X_val = scaler.transform(X_val.reshape(X_val.shape[0], -1)).reshape(X_val.shape)

        C, T = X_train.shape[1], X_train.shape[2]
        n_classes = len(np.unique(y_train))

        print(f"Data shape - Train: {X_train.shape}, Val: {X_val.shape}")
        print(f"Number of classes: {n_classes}")

        # to tensors
        X_train = X_train[:, np.newaxis, :, :]
        X_val = X_val[:, np.newaxis, :, :]
        X_train = torch.FloatTensor(X_train)
        y_train = torch.LongTensor(y_train)
        X_val = torch.FloatTensor(X_val)
        y_val = torch.LongTensor(y_val)

        train_loader = DataLoader(TensorDataset(X_train, y_train), batch_size=64, shuffle=True)
        val_loader = DataLoader(TensorDataset(X_val, y_val), batch_size=64, shuffle=False)
        model = create_eeg_tcnet_fixed(n_chan=C, n_cls=n_classes).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

        num_epochs = 100
        best_val_acc = 0
        best_val_kappa = 0

        loss_history = []
        val_acc_history = []

        for epoch in range(num_epochs):
            model.train()
            train_loss = 0.0
            for batch_x, batch_y in train_loader:
                batch_x, batch_y = batch_x.to(device), batch_y.to(device)
                optimizer.zero_grad()
                outputs = model(batch_x)
                loss = criterion(outputs, batch_y)
                loss.backward()
                optimizer.step()
                train_loss += loss.item()

            avg_train_loss = train_loss / len(train_loader)
            loss_history.append(avg_train_loss)

            model.eval()
            val_preds, val_true = [], []
            with torch.no_grad():
                for batch_x, batch_y in val_loader:
                    batch_x, batch_y = batch_x.to(device), batch_y.to(device)
                    outputs = model(batch_x)
                    _, preds = torch.max(outputs, 1)
                    val_preds.extend(preds.cpu().numpy())
                    val_true.extend(batch_y.cpu().numpy())

            val_acc = accuracy_score(val_true, val_preds)
            val_kappa = cohen_kappa_score(val_true, val_preds)
            val_acc_history.append(val_acc)

            if val_acc > best_val_acc:
                best_val_acc = val_acc
                best_val_kappa = val_kappa

            if (epoch + 1) % 10 == 0:
                print(f"Epoch {epoch+1}/{num_epochs} - Loss: {avg_train_loss:.4f}, "
                      f"Val Acc: {val_acc:.4f}, Val Kappa: {val_kappa:.4f}")

        all_results.append(best_val_acc)
        all_kappa_scores.append(best_val_kappa)
        all_loss_histories.append(loss_history)
        all_val_acc_histories.append(val_acc_history)

        print(f"Best Results (Subject {test_subj}): "
              f"Accuracy: {best_val_acc:.4f}, Kappa: {best_val_kappa:.4f}")
    if all_results:
        mean_acc = np.mean(all_results)
        std_acc = np.std(all_results)
        mean_kappa = np.mean(all_kappa_scores)

        print("\n" + "="*50)
        print("FINAL RESULTS:")
        print("="*50)
        for i, (acc, kappa) in enumerate(zip(all_results, all_kappa_scores), start=1):
            print(f"Subject {i}: Accuracy = {acc:.4f}, Kappa = {kappa:.4f}")

        print(f"\nOverall: Accuracy = {mean_acc:.4f} ± {std_acc:.4f}, "
              f"Kappa = {mean_kappa:.4f}")
        plot_training_curves(all_loss_histories, all_val_acc_histories, subjects, num_epochs)

        return all_results, all_kappa_scores
    else:
        print("No results to report.")
        return [], []


def plot_training_curves(all_loss_histories, all_val_acc_histories, subjects, num_epochs):
    plt.rcParams['font.sans-serif'] = ['Arial']
    plt.rcParams['axes.unicode_minus'] = False

    colors = plt.cm.Set3(np.linspace(0, 1, len(subjects)))
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8))
    epochs_range = range(1, num_epochs + 1)

    for i, (loss_h, val_h) in enumerate(zip(all_loss_histories, all_val_acc_histories)):
        ax1.plot(epochs_range, loss_h, color=colors[i], label=f'Subject {subjects[i]}')
        ax2.plot(epochs_range, val_h, color=colors[i], label=f'Subject {subjects[i]}')

    import matplotlib.ticker as ticker
    ax1.xaxis.set_major_locator(ticker.MultipleLocator(20))
    ax2.xaxis.set_major_locator(ticker.MultipleLocator(20))

    ax1.set_title('Training Loss - EEG-TCNet')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Loss')
    ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax1.grid(True)

    ax2.set_title('Validation Accuracy - EEG-TCNet')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Accuracy')
    ax2.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax2.grid(True)

    plt.tight_layout()
    plt.savefig('eeg_tcnet_training_curves.png', dpi=300, bbox_inches='tight')
    plt.show()


if __name__ == "__main__":
    results, kappa_scores = train_eeg_tcnet()
# Out:
# WARNING:moabb.paradigms.motor_imagery:Choosing from all possible events
# Subjects: [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Using device: cuda
# Data shape - Train: (4608, 22, 876), Val: (576, 22, 876)
# Number of classes: 4
# Epoch 10/100 - Loss: 1.1075, Val Acc: 0.5017, Val Kappa: 0.3356
# Epoch 20/100 - Loss: 1.0355, Val Acc: 0.5399, Val Kappa: 0.3866
# Epoch 30/100 - Loss: 0.9930, Val Acc: 0.5608, Val Kappa: 0.4144
# Epoch 40/100 - Loss: 0.9733, Val Acc: 0.5677, Val Kappa: 0.4236
# Epoch 50/100 - Loss: 0.9558, Val Acc: 0.5625, Val Kappa: 0.4167
# Epoch 60/100 - Loss: 0.9366, Val Acc: 0.5729, Val Kappa: 0.4306
# Epoch 70/100 - Loss: 0.9372, Val Acc: 0.5990, Val Kappa: 0.4653
# Epoch 80/100 - Loss: 0.9322, Val Acc: 0.5642, Val Kappa: 0.4190
# Epoch 90/100 - Loss: 0.9241, Val Acc: 0.5712, Val Kappa: 0.4282
# Epoch 100/100 - Loss: 0.8970, Val Acc: 0.5920, Val Kappa: 0.4560
# Best Results (Subject 1): Accuracy: 0.6215, Kappa: 0.4954
# Data shape - Train: (4608, 22, 876), Val: (576, 22, 876)
# Number of classes: 4
# Epoch 10/100 - Loss: 1.0409, Val Acc: 0.2847, Val Kappa: 0.0463
# Epoch 20/100 - Loss: 0.9524, Val Acc: 0.2674, Val Kappa: 0.0231
# Epoch 30/100 - Loss: 0.8922, Val Acc: 0.3003, Val Kappa: 0.0671
# Epoch 40/100 - Loss: 0.8617, Val Acc: 0.3177, Val Kappa: 0.0903
# Epoch 50/100 - Loss: 0.8392, Val Acc: 0.3090, Val Kappa: 0.0787
# Epoch 60/100 - Loss: 0.8371, Val Acc: 0.2830, Val Kappa: 0.0440
# Epoch 70/100 - Loss: 0.8259, Val Acc: 0.2882, Val Kappa: 0.0509
# Epoch 80/100 - Loss: 0.7894, Val Acc: 0.2674, Val Kappa: 0.0231
# Epoch 90/100 - Loss: 0.7879, Val Acc: 0.2847, Val Kappa: 0.0463
# Epoch 100/100 - Loss: 0.7782, Val Acc: 0.2917, Val Kappa: 0.0556
# Best Results (Subject 2): Accuracy: 0.3281, Kappa: 0.1042
# Data shape - Train: (4608, 22, 876), Val: (576, 22, 876)
# Number of classes: 4
# Epoch 10/100 - Loss: 1.1266, Val Acc: 0.7569, Val Kappa: 0.6759
# Epoch 20/100 - Loss: 1.0528, Val Acc: 0.6806, Val Kappa: 0.5741
# Epoch 30/100 - Loss: 1.0189, Val Acc: 0.7049, Val Kappa: 0.6065
# Epoch 40/100 - Loss: 0.9976, Val Acc: 0.6684, Val Kappa: 0.5579
# Epoch 50/100 - Loss: 0.9745, Val Acc: 0.6632, Val Kappa: 0.5509
# Epoch 60/100 - Loss: 0.9445, Val Acc: 0.6562, Val Kappa: 0.5417
# Epoch 70/100 - Loss: 0.9447, Val Acc: 0.6875, Val Kappa: 0.5833
# Epoch 80/100 - Loss: 0.9103, Val Acc: 0.6840, Val Kappa: 0.5787
# Epoch 90/100 - Loss: 0.8941, Val Acc: 0.6059, Val Kappa: 0.4745
# Epoch 100/100 - Loss: 0.9042, Val Acc: 0.6302, Val Kappa: 0.5069
# Best Results (Subject 3): Accuracy: 0.7622, Kappa: 0.6829
# Data shape - Train: (4608, 22, 876), Val: (576, 22, 876)
# Number of classes: 4
# Epoch 10/100 - Loss: 1.0665, Val Acc: 0.3542, Val Kappa: 0.1389
# Epoch 20/100 - Loss: 0.9876, Val Acc: 0.3715, Val Kappa: 0.1620
# Epoch 30/100 - Loss: 0.9398, Val Acc: 0.3385, Val Kappa: 0.1181
# Epoch 40/100 - Loss: 0.9079, Val Acc: 0.3889, Val Kappa: 0.1852
# Epoch 50/100 - Loss: 0.8787, Val Acc: 0.3663, Val Kappa: 0.1551
# Epoch 60/100 - Loss: 0.8761, Val Acc: 0.3351, Val Kappa: 0.1134
# Epoch 70/100 - Loss: 0.8598, Val Acc: 0.3681, Val Kappa: 0.1574
# Epoch 80/100 - Loss: 0.8300, Val Acc: 0.3507, Val Kappa: 0.1343
# Epoch 90/100 - Loss: 0.8098, Val Acc: 0.3455, Val Kappa: 0.1273
# Epoch 100/100 - Loss: 0.7993, Val Acc: 0.3854, Val Kappa: 0.1806
# Best Results (Subject 4): Accuracy: 0.4184, Kappa: 0.2245
# Data shape - Train: (4608, 22, 876), Val: (576, 22, 876)
# Number of classes: 4
# Epoch 10/100 - Loss: 1.0550, Val Acc: 0.2604, Val Kappa: 0.0139
# Epoch 20/100 - Loss: 0.9493, Val Acc: 0.2674, Val Kappa: 0.0231
# Epoch 30/100 - Loss: 0.9127, Val Acc: 0.2483, Val Kappa: -0.0023
# Epoch 40/100 - Loss: 0.8812, Val Acc: 0.2500, Val Kappa: 0.0000
# Epoch 50/100 - Loss: 0.8437, Val Acc: 0.2743, Val Kappa: 0.0324
# Epoch 60/100 - Loss: 0.8364, Val Acc: 0.2708, Val Kappa: 0.0278
# Epoch 70/100 - Loss: 0.8242, Val Acc: 0.2760, Val Kappa: 0.0347
# Epoch 80/100 - Loss: 0.8093, Val Acc: 0.2674, Val Kappa: 0.0231
# Epoch 90/100 - Loss: 0.8013, Val Acc: 0.2847, Val Kappa: 0.0463
# Epoch 100/100 - Loss: 0.7969, Val Acc: 0.2483, Val Kappa: -0.0023
# Best Results (Subject 5): Accuracy: 0.2917, Kappa: 0.0556
# Data shape - Train: (4608, 22, 876), Val: (576, 22, 876)
# Number of classes: 4
# Epoch 10/100 - Loss: 1.0446, Val Acc: 0.3385, Val Kappa: 0.1181
# Epoch 20/100 - Loss: 0.9725, Val Acc: 0.3455, Val Kappa: 0.1273
# Epoch 30/100 - Loss: 0.9068, Val Acc: 0.3420, Val Kappa: 0.1227
# Epoch 40/100 - Loss: 0.8729, Val Acc: 0.3264, Val Kappa: 0.1019
# Epoch 50/100 - Loss: 0.8531, Val Acc: 0.3038, Val Kappa: 0.0718
# Epoch 60/100 - Loss: 0.8482, Val Acc: 0.3108, Val Kappa: 0.0810
# Epoch 70/100 - Loss: 0.8279, Val Acc: 0.3455, Val Kappa: 0.1273
# Epoch 80/100 - Loss: 0.8219, Val Acc: 0.3108, Val Kappa: 0.0810
# Epoch 90/100 - Loss: 0.8029, Val Acc: 0.3090, Val Kappa: 0.0787
# Epoch 100/100 - Loss: 0.7903, Val Acc: 0.3194, Val Kappa: 0.0926
# Best Results (Subject 6): Accuracy: 0.3715, Kappa: 0.1620
# Data shape - Train: (4608, 22, 876), Val: (576, 22, 876)
# Number of classes: 4
# Epoch 10/100 - Loss: 1.0751, Val Acc: 0.2795, Val Kappa: 0.0394
# Epoch 20/100 - Loss: 1.0030, Val Acc: 0.3108, Val Kappa: 0.0810
# Epoch 30/100 - Loss: 0.9550, Val Acc: 0.3212, Val Kappa: 0.0949
# Epoch 40/100 - Loss: 0.9227, Val Acc: 0.3056, Val Kappa: 0.0741
# Epoch 50/100 - Loss: 0.9096, Val Acc: 0.3247, Val Kappa: 0.0995
# Epoch 60/100 - Loss: 0.8808, Val Acc: 0.3073, Val Kappa: 0.0764
# Epoch 70/100 - Loss: 0.8633, Val Acc: 0.3194, Val Kappa: 0.0926
# Epoch 80/100 - Loss: 0.8504, Val Acc: 0.3299, Val Kappa: 0.1065
# Epoch 90/100 - Loss: 0.8482, Val Acc: 0.3142, Val Kappa: 0.0856
# Epoch 100/100 - Loss: 0.8232, Val Acc: 0.3212, Val Kappa: 0.0949
# Best Results (Subject 7): Accuracy: 0.3681, Kappa: 0.1574
# Data shape - Train: (4608, 22, 876), Val: (576, 22, 876)
# Number of classes: 4
# Epoch 10/100 - Loss: 1.1389, Val Acc: 0.5851, Val Kappa: 0.4468
# Epoch 20/100 - Loss: 1.0567, Val Acc: 0.6233, Val Kappa: 0.4977
# Epoch 30/100 - Loss: 1.0127, Val Acc: 0.6302, Val Kappa: 0.5069
# Epoch 40/100 - Loss: 0.9738, Val Acc: 0.6979, Val Kappa: 0.5972
# Epoch 50/100 - Loss: 0.9543, Val Acc: 0.6007, Val Kappa: 0.4676
# Epoch 60/100 - Loss: 0.9344, Val Acc: 0.6215, Val Kappa: 0.4954
# Epoch 70/100 - Loss: 0.9091, Val Acc: 0.6632, Val Kappa: 0.5509
# Epoch 80/100 - Loss: 0.8910, Val Acc: 0.6094, Val Kappa: 0.4792
# Epoch 90/100 - Loss: 0.8923, Val Acc: 0.6771, Val Kappa: 0.5694
# Epoch 100/100 - Loss: 0.8855, Val Acc: 0.6493, Val Kappa: 0.5324
# Best Results (Subject 8): Accuracy: 0.6979, Kappa: 0.5972
# Data shape - Train: (4608, 22, 876), Val: (576, 22, 876)
# Number of classes: 4
# Epoch 10/100 - Loss: 1.1220, Val Acc: 0.5104, Val Kappa: 0.3472
# Epoch 20/100 - Loss: 1.0500, Val Acc: 0.5260, Val Kappa: 0.3681
# Epoch 30/100 - Loss: 1.0163, Val Acc: 0.5469, Val Kappa: 0.3958
# Epoch 40/100 - Loss: 0.9820, Val Acc: 0.5764, Val Kappa: 0.4352
# Epoch 50/100 - Loss: 0.9623, Val Acc: 0.5764, Val Kappa: 0.4352
# Epoch 60/100 - Loss: 0.9408, Val Acc: 0.5625, Val Kappa: 0.4167
# Epoch 70/100 - Loss: 0.9302, Val Acc: 0.5451, Val Kappa: 0.3935
# Epoch 80/100 - Loss: 0.9137, Val Acc: 0.5556, Val Kappa: 0.4074
# Epoch 90/100 - Loss: 0.8914, Val Acc: 0.5833, Val Kappa: 0.4444
# Epoch 100/100 - Loss: 0.8841, Val Acc: 0.5747, Val Kappa: 0.4329
# Best Results (Subject 9): Accuracy: 0.6146, Kappa: 0.4861
#
# ==================================================
# FINAL RESULTS:
# ==================================================
# Subject 1: Accuracy = 0.6215, Kappa = 0.4954
# Subject 2: Accuracy = 0.3281, Kappa = 0.1042
# Subject 3: Accuracy = 0.7622, Kappa = 0.6829
# Subject 4: Accuracy = 0.4184, Kappa = 0.2245
# Subject 5: Accuracy = 0.2917, Kappa = 0.0556
# Subject 6: Accuracy = 0.3715, Kappa = 0.1620
# Subject 7: Accuracy = 0.3681, Kappa = 0.1574
# Subject 8: Accuracy = 0.6979, Kappa = 0.5972
# Subject 9: Accuracy = 0.6146, Kappa = 0.4861
#
# Overall: Accuracy = 0.4971 ± 0.1664, Kappa = 0.3295
